# %% [markdown]
# ### Testing different beautification techniques

# %%
import sys, cv2
sys.path.append('..')
from Preprocessing.preproc import rotate_image, beautify_frame
import glob
import matplotlib.pyplot as plt
from libimage import RPiCamV3_img_shape

root = '/Users/cyrilmonette/Library/CloudStorage/SynologyDrive-data/24.09-24.10_observation_OH/Images/h1r1_1minute/'
# List all files and take the 100th one
flist = glob.glob(root + "*.jpg")
flist = sorted(flist)

img = cv2.imread(flist[60000], cv2.IMREAD_GRAYSCALE)
last_img = cv2.imread(flist[-1], cv2.IMREAD_GRAYSCALE)
processed_img = beautify_frame(img)
processed_last_img = beautify_frame(last_img)

# Show original and processed image side by side with matplotlib
plt.figure(figsize=(16, 8))
plt.subplot(2, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original image')
plt.subplot(2, 2, 2)
plt.imshow(processed_img, cmap='gray')
plt.title('Processed image')
plt.subplot(2, 2, 3)
plt.imshow(last_img, cmap='gray')
plt.title('Original image')
plt.subplot(2, 2, 4)
plt.imshow(processed_last_img, cmap='gray')
plt.title('Processed image')
plt.show()

# Save processed image as output.jpg in current directory and input image as input.jpg
# cv2.imwrite('output.jpg', processed_img)
# cv2.imwrite('input.jpg', img)

# %%
# Here I want to test a different BGR function that could optimise speed ! Conclusion: alternative2 is the exact same as cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

def grayscale(bgr):
    result = ((bgr[..., 0] * 0.0721) +
              (bgr[..., 1] * 0.7154) +
              (bgr[..., 2] * 0.2125))
    return result

def grayscale2(bgr):
    result = ((bgr[..., 0] * 0.114) +
              (bgr[..., 1] * 0.587) +
              (bgr[..., 2] * 0.299))
    return result

root = '/Users/cyrilmonette/Library/CloudStorage/SynologyDrive-data/24.09-24.10_observation_OH/Images/h1r1_1minute/'
# List all files and take the 100th one
flist = glob.glob(root + "*.jpg")
flist = sorted(flist)

img = cv2.imread(flist[100])

gray_classic = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_alternative = grayscale(img)
gray_alternative2 = grayscale2(img)
pp_classic = beautify_frame(gray_classic)
pp_alternative = beautify_frame(gray_alternative)
pp_alternative2 = beautify_frame(gray_alternative2)

# Show the two grayscale images side by side
plt.figure(figsize=(20, 8))
plt.subplot(2, 3, 1)
plt.imshow(gray_classic, cmap='gray')
plt.title('Classic grayscale')
plt.subplot(2, 3, 2)
plt.imshow(gray_alternative, cmap='gray')
plt.title('Alternative grayscale')
plt.subplot(2, 3, 3)
plt.imshow(gray_alternative2, cmap='gray')
plt.title('Alternative grayscale 2')
plt.subplot(2, 3, 4)
plt.imshow(pp_classic, cmap='gray')
plt.title('Classic grayscale')
plt.subplot(2, 3, 5)
plt.imshow(pp_alternative, cmap='gray')
plt.title('Alternative grayscale')
plt.subplot(2, 3, 6)
plt.imshow(pp_alternative2, cmap='gray')
plt.title('Alternative grayscale 2')
plt.show()

# Save pp_classic and pp_alternative as output_classic.jpg and output_alternative.jpg
cv2.imwrite('output_classic.jpg', pp_classic)
cv2.imwrite('output_alternative.jpg', pp_alternative)
cv2.imwrite('output_alternative2.jpg', pp_alternative2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 20
#      17 flist = glob.glob(root + "*.png")
#      18 flist = sorted(flist)
# ---> 20 img = cv.imread(flist[100])
#      22 gray_classic = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#      23 gray_alternative = grayscale(img)
#
# IndexError: list index out of range

# %%
# For the same initial image, show the image in 16-bit grayscale and in BGR
img_bgr = cv2.imread(flist[1000], cv2.IMREAD_COLOR)
gray_16bit = cv2.imread(flist[1000], cv2.IMREAD_ANYDEPTH)
gray_8bit = cv2.imread(flist[1000], cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(16, 8))
plt.subplot(1, 3, 1)
plt.imshow(gray_16bit, cmap='gray')
plt.title('16-bit grayscale image')
plt.subplot(1, 3, 2)
plt.imshow(gray_8bit, cmap='gray')
plt.title('8-bit grayscale image')
plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.title('BGR image')
plt.show()

# Test to see the min and max values in gray_16bit
print('Min value:', np.min(gray_16bit))
print('Max value:', np.max(gray_16bit))

# Test to see the min and max values in gray_8bit
print('Min value:', np.min(gray_8bit))
print('Max value:', np.max(gray_8bit))

# Test to see the min and max values in img_bgr
print('Min value:', np.min(img_bgr))
print('Max value:', np.max(img_bgr))
# What format does img_bgr have?
print('Image format:', img_bgr.dtype)
print('Image shape:', img_bgr.shape)

# Convert the rgb image to 16-bit grayscale
gray_16bit_bgr = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
print('Image format:', gray_16bit_bgr.dtype)
# Out:
# Min value: 0
# Max value: 255
# Min value: 0
# Max value: 255
# Min value: 0
# Max value: 255
# Image format: uint8
# Image shape: (2592, 4608, 3)
# Image format: uint8

# %% [markdown]
# ## Testing preprocessing

# %%
rootpath_imgs = '/Users/cyrilmonette/Library/CloudStorage/SynologyDrive-data/22.12-23.02_actuation_OH/Images/high-fps/subset'     # For images

rpi_imgs = rootpath_imgs + "/h5r2"

# Take the first image in r1_imgs and read it with cv.imread, then show it with matplotlib
flist = glob.glob(rpi_imgs + "/*.jpg")
flist = sorted(flist)
img = cv2.imread(flist[0], cv2.IMREAD_GRAYSCALE)
img = rotate_image(img, 1.5)
# Print img shape
print('Image shape:', img.shape)
img = img[600:2400, 350:3500]

# Then scale the image such that the final size is RPiCamV3_img_shape
img = cv2.resize(img, (RPiCamV3_img_shape[1], RPiCamV3_img_shape[0]))

img = beautify_frame(img)

fig, ax = plt.subplots(figsize=(10, 10))
plt.imshow(img, cmap='gray')
plt.title('First image in h5r2')
plt.show()
# Out:
# Image shape: (3040, 4056)
